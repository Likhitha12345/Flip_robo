# %%
# Importing Libraries
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# %%
driver = webdriver.Chrome(r'C:\Users\rjhcl\Desktop\web driver\chromedriver.exe')

# %%
url='https://www.yatra.com/'
driver.get(url)

# %%
search_button = driver.find_element_by_id('BE_flight_flsearch_btn')
search_button.click()

# %%
Airline=[]
Soruce=[]
Destination=[]
Departure_time=[]
Arrival_time=[]
Duration=[]
Total_stop=[]
Price=[]

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//span[@class = 'i-b text ellipsis']"):
        Airline.append(j.text)
Airline
# Out:
# ['Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//p[@title = 'New Delhi']"):
        Soruce.append(j.text)
Soruce
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//p[@title = 'Mumbai']"):
        Destination.append(j.text)
Destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'i-b pr']"):
        Departure_time.append(j.text)
Departure_time
# Out:
# ['22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
#  '06:20',
#  '04:45',
#  '11:20',
#  '04:25',
#  '01:05',
#  '08:45',
#  '08:10',
#  '07:30',
#  '06:35',
#  '09:30',
#  '08:50',
#  '18:55',
#  '23:15',
#  '10:45',
#  '05:15',
#  '09:30',
#  '06:00',
#  '22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
#  '06:20',
#  '04:45',
#  '11:20',
#  '04:25',
#  '01:05',
#  '08:45',
#  '08:10',
#  '07:30',
#  '06:35',
#  '09:30',
#  '08:50',
#  '18:55',
#  '23:15',
#  '10:45',
#  '05:15',
#  '09:30',
#  '06:00',
#  '22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
#  '06:20',
#  '04:45',
#  '11:20',
#  '04:25',
#  '01:05',
#  '08:45',
#  '08:10',
#  '07:30',
#  '06:35',
#  '09:30',
#  '08:50',
#  '18:55',
#  '23:15',
#  '10:45',
#  '05:15',
#  '09:30',
#  '06:00',
#  '22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//p[@class = 'bold fs-15 mb-2 pr time']"):
        Arrival_time.append(j.text)
Arrival_time
# Out:
# ['12:25\n+ 1 day',
#  '08:10',
#  '10:10',
#  '04:15',
#  '15:45',
#  '08:40',
#  '09:25',
#  '09:35',
#  '08:40',
#  '07:10',
#  '18:00',
#  '06:35',
#  '03:20',
#  '11:05',
#  '10:20',
#  '09:45',
#  '10:15',
#  '11:45',
#  '11:10',
#  '21:05',
#  '01:25\n+ 1 day',
#  '13:05',
#  '10:05',
#  '11:35',
#  '10:40',
#  '12:25\n+ 1 day',
#  '08:10',
#  '10:10',
#  '04:15',
#  '15:45',
#  '08:40',
#  '09:25',
#  '09:35',
#  '08:40',
#  '07:10',
#  '18:00',
#  '06:35',
#  '03:20',
#  '11:05',
#  '10:20',
#  '09:45',
#  '10:15',
#  '11:45',
#  '11:10',
#  '21:05',
#  '01:25\n+ 1 day',
#  '13:05',
#  '10:05',
#  '11:35',
#  '10:40',
#  '12:25\n+ 1 day',
#  '08:10',
#  '10:10',
#  '04:15',
#  '15:45',
#  '08:40',
#  '09:25',
#  '09:35',
#  '08:40',
#  '07:10',
#  '18:00',
#  '06:35',
#  '03:20',
#  '11:05',
#  '10:20',
#  '09:45',
#  '10:15',
#  '11:45',
#  '11:10',
#  '21:05',
#  '01:25\n+ 1 day',
#  '13:05',
#  '10:05',
#  '11:35',
#  '10:40',
#  '12:25\n+ 1 day',
#  '08:10',
#  '10:10',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//p[@class = 'fs-12 bold du mb-2']"):
        Duration.append(j.text)
Duration
# Out:
# ['14h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '6h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '6h 40m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '3h 40m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 20m',
#  '4h 50m',
#  '2h 05m',
#  '4h 40m',
#  '14h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '6h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '6h 40m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '3h 40m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 20m',
#  '4h 50m',
#  '2h 05m',
#  '4h 40m',
#  '14h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '6h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '6h 40m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '3h 40m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 20m',
#  '4h 50m',
#  '2h 05m',
#  '4h 40m',
#  '14h 15m',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//span[@class = 'dotted-borderbtm']"):
        Total_stop.append(j.text)
Total_stop
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']"):
        Price.append(j.text)
Price
# Out:
# ['5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,139',
#  '6,585',
#  '6,795',
#  '7,110',
#  '7,530',
#  '8,264',
#  '8,370',
#  '8,790',
#  '9,104',
#  '9,420',
#  '9,420',
#  '9,420',
#  '9,525',
#  '9,761',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,139',
#  '6,585',
#  '6,795',
#  '7,110',
#  '7,530',
#  '8,264',
#  '8,370',
#  '8,790',
#  '9,104',
#  '9,420',
#  '9,420',
#  '9,420',
#  '9,525',
#  '9,761',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,139',
#  '6,585',
#  '6,795',
#  '7,110',
#  '7,530',
#  '8,264',
#  '8,370',
#  '8,790',
#  '9,104',
#  '9,420',
#  '9,420',
#  '9,420',
#  '9,525',
#  '9,761',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
# ...

# %%
print(len(Airline),len(Soruce),len(Destination),len(Departure_time),len(Arrival_time),len(Duration),len(Total_stop),len(Price))
# Out:
# 250 250 250 250 250 250 180 250

# %%
Flight1=pd.DataFrame({})
Flight1["Airline"]=Airline[:180]
Flight1["Soruce"]=Soruce[:180]
Flight1["Destination"]=Destination[:180]
Flight1["Departure_time"]=Departure_time[:180]
Flight1["Arrival_time"]=Arrival_time[:180]
Flight1["Duration"]=Duration[:180]
Flight1["Total_stop"]=Total_stop[:180]
Flight1["Price"]=Price[:180]
Flight1[:180]
# Out:
#       Airline     Soruce Destination Departure_time    Arrival_time Duration  \
# 0    Air Asia  New Delhi      Mumbai          22:10  12:25\n+ 1 day  14h 15m
# 1    Go First  New Delhi      Mumbai          06:00           08:10   2h 10m
# 2    Go First  New Delhi      Mumbai          08:00           10:10   2h 10m
# 3    Go First  New Delhi      Mumbai          02:00           04:15   2h 15m
# 4    Go First  New Delhi      Mumbai          09:00           15:45   6h 45m
# ..        ...        ...         ...            ...             ...      ...
# 175  Air Asia  New Delhi      Mumbai          22:10  12:25\n+ 1 day  14h 15m
# 176  Go First  New Delhi      Mumbai          06:00           08:10   2h 10m
# 177  Go First  New Delhi      Mumbai          08:00           10:10   2h 10m
# 178  Go First  New Delhi      Mumbai          02:00           04:15   2h 15m
# 179  Go First  New Delhi      Mumbai          09:00           15:45   6h 45m
#
#     Total_stop  Price
# ...

# %%
url='https://www.makemytrip.com/'
driver.get(url)

# %%
search_button = driver.find_element_by_xpath("//a[@class = 'primaryBtn font24 latoBold widgetSearchBtn ']")
search_button.click()

# %%
Airline=[]
Source=[]
Destination=[]
Departure_time=[]
Arrival_time=[]
Duration=[]
Total_stop=[]
Price=[]

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//span[@class = 'boldFont blackText airlineName']"):
        Airline.append(j.text)
Airline
# Out:
# ['AirAsia',
#  'Go First',
#  'Go First',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'IndiGo',
#  'IndiGo',
#  'Spicejet',
#  'Spicejet',
#  'Spicejet',
#  'AirAsia',
#  '',
#  '',
#  '',
#  'Spicejet',
#  'IndiGo',
#  'AirAsia',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'AirAsia',
#  'Go First',
#  'Go First',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'IndiGo',
#  'IndiGo',
#  'Spicejet',
#  'Spicejet',
#  'Spicejet',
#  'AirAsia',
#  '',
#  '',
#  '',
#  'Spicejet',
#  'IndiGo',
#  'AirAsia',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'AirAsia',
#  'Go First',
#  'Go First',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'IndiGo',
#  'IndiGo',
#  'Spicejet',
#  'Spicejet',
#  'Spicejet',
#  'AirAsia',
#  '',
#  '',
#  '',
#  'Spicejet',
#  'IndiGo',
#  'AirAsia',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'AirAsia',
#  'Go First',
#  'Go First',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'timingOptionOuter']/label/div/div/div[1]/div[1]/p[2]"):
        Source.append(j.text)
Source
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  '',
#  '',
#  '',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  '',
#  '',
#  '',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  '',
#  '',
#  '',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'timingOptionOuter']/label/div/div/div[3]/div[1]/p[2]"):
        Destination.append(j.text)
Destination
# Out:
# ['Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  '',
#  '',
#  '',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  '',
#  '',
#  '',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  '',
#  '',
#  '',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'timingOptionOuter']/label/div/div/div[1]/div[1]/p[1]/span"):
        Departure_time.append(j.text)
Departure_time
# Out:
# ['04:55',
#  '06:05',
#  '09:00',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '04:15',
#  '06:10',
#  '08:40',
#  '18:25',
#  '05:35',
#  '21:00',
#  '',
#  '',
#  '',
#  '22:20',
#  '07:55',
#  '13:20',
#  '21:25',
#  '21:15',
#  '06:15',
#  '02:30',
#  '22:50',
#  '07:20',
#  '04:55',
#  '06:05',
#  '09:00',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '04:15',
#  '06:10',
#  '08:40',
#  '18:25',
#  '05:35',
#  '21:00',
#  '',
#  '',
#  '',
#  '22:20',
#  '07:55',
#  '13:20',
#  '21:25',
#  '21:15',
#  '06:15',
#  '02:30',
#  '22:50',
#  '07:20',
#  '04:55',
#  '06:05',
#  '09:00',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '04:15',
#  '06:10',
#  '08:40',
#  '18:25',
#  '05:35',
#  '21:00',
#  '',
#  '',
#  '',
#  '22:20',
#  '07:55',
#  '13:20',
#  '21:25',
#  '21:15',
#  '06:15',
#  '02:30',
#  '22:50',
#  '07:20',
#  '04:55',
#  '06:05',
#  '09:00',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '04:15',
#  '06:10',
#  '08:40',
#  '18:25',
#  '05:35',
#  '21:00',
#  '',
#  '',
#  '',
#  '22:20',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'timingOptionOuter']/label/div/div/div[3]/div[1]/p[1]/span"):
        Arrival_time.append(j.text)
Arrival_time
# Out:
# ['15:50',
#  '08:40',
#  '16:25',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '07:10',
#  '08:50',
#  '16:25',
#  '21:10',
#  '08:05',
#  '11:35',
#  '',
#  '',
#  '',
#  '01:05',
#  '13:20',
#  '21:45',
#  '00:20',
#  '06:55',
#  '09:00',
#  '05:25',
#  '01:45',
#  '10:15',
#  '15:50',
#  '08:40',
#  '16:25',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '07:10',
#  '08:50',
#  '16:25',
#  '21:10',
#  '08:05',
#  '11:35',
#  '',
#  '',
#  '',
#  '01:05',
#  '13:20',
#  '21:45',
#  '00:20',
#  '06:55',
#  '09:00',
#  '05:25',
#  '01:45',
#  '10:15',
#  '15:50',
#  '08:40',
#  '16:25',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '07:10',
#  '08:50',
#  '16:25',
#  '21:10',
#  '08:05',
#  '11:35',
#  '',
#  '',
#  '',
#  '01:05',
#  '13:20',
#  '21:45',
#  '00:20',
#  '06:55',
#  '09:00',
#  '05:25',
#  '01:45',
#  '10:15',
#  '15:50',
#  '08:40',
#  '16:25',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '07:10',
#  '08:50',
#  '16:25',
#  '21:10',
#  '08:05',
#  '11:35',
#  '',
#  '',
#  '',
#  '01:05',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//div[@class = 'timingOptionOuter']/label/div/div/div[2]/p"):
        Duration.append(j.text)
Duration
# Out:
# ['10 h 55 m',
#  '02 h 35 m',
#  '07 h 25 m',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '02 h 55 m',
#  '02 h 40 m',
#  '07 h 45 m',
#  '26 h 45 m',
#  '02 h 30 m',
#  '14 h 35 m',
#  '',
#  '',
#  '',
#  '02 h 45 m',
#  '05 h 25 m',
#  '08 h 25 m',
#  '02 h 55 m',
#  '09 h 40 m',
#  '02 h 45 m',
#  '02 h 55 m',
#  '02 h 55 m',
#  '02 h 55 m',
#  '10 h 55 m',
#  '02 h 35 m',
#  '07 h 25 m',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '02 h 55 m',
#  '02 h 40 m',
#  '07 h 45 m',
#  '26 h 45 m',
#  '02 h 30 m',
#  '14 h 35 m',
#  '',
#  '',
#  '',
#  '02 h 45 m',
#  '05 h 25 m',
#  '08 h 25 m',
#  '02 h 55 m',
#  '09 h 40 m',
#  '02 h 45 m',
#  '02 h 55 m',
#  '02 h 55 m',
#  '02 h 55 m',
#  '10 h 55 m',
#  '02 h 35 m',
#  '07 h 25 m',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '02 h 55 m',
#  '02 h 40 m',
#  '07 h 45 m',
#  '26 h 45 m',
#  '02 h 30 m',
#  '14 h 35 m',
#  '',
#  '',
#  '',
#  '02 h 45 m',
#  '05 h 25 m',
#  '08 h 25 m',
#  '02 h 55 m',
#  '09 h 40 m',
#  '02 h 45 m',
#  '02 h 55 m',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//p[@class = 'flightsLayoverInfo']"):
        Total_stop.append(j.text)
Total_stop
# Out:
# ['1 stop via Kochi',
#  'Non stop',
#  '1 stop via Lucknow',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Non stop',
#  'Non stop',
#  '1 stop via Pune',
#  '1 stop via Chennai',
#  'Non stop',
#  '1 stop via Kolkata',
#  '',
#  '',
#  '',
#  'Non stop',
#  '1 stop via Hyderabad',
#  '1 stop via Ranchi',
#  'Non stop',
#  '1 stop via Hyderabad',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  '1 stop via Kochi',
#  'Non stop',
#  '1 stop via Lucknow',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Non stop',
#  'Non stop',
#  '1 stop via Pune',
#  '1 stop via Chennai',
#  'Non stop',
#  '1 stop via Kolkata',
#  '',
#  '',
#  '',
#  'Non stop',
#  '1 stop via Hyderabad',
#  '1 stop via Ranchi',
#  'Non stop',
#  '1 stop via Hyderabad',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  '1 stop via Kochi',
#  'Non stop',
#  '1 stop via Lucknow',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Non stop',
#  'Non stop',
#  '1 stop via Pune',
#  '1 stop via Chennai',
#  'Non stop',
# ...

# %%
for i in range(0,10):
    for j in driver.find_elements_by_xpath("//p[@class = 'blackText fontSize18 blackFont white-space-no-wrap']"):
        Price.append(j.text)
Price
# Out:
# ['₹ 7,423',
#  '₹ 7,424',
#  '₹ 7,424',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,740',
#  '₹ 7,741',
#  '',
#  '',
#  '',
#  '₹ 9,210',
#  '₹ 9,362',
#  '₹ 9,657',
#  '₹ 9,788',
#  '₹ 10,008',
#  '₹ 10,050',
#  '₹ 10,103',
#  '₹ 10,103',
#  '₹ 10,628',
#  '₹ 7,423',
#  '₹ 7,424',
#  '₹ 7,424',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,740',
#  '₹ 7,741',
#  '',
#  '',
#  '',
#  '₹ 9,210',
#  '₹ 9,362',
#  '₹ 9,657',
#  '₹ 9,788',
#  '₹ 10,008',
#  '₹ 10,050',
#  '₹ 10,103',
#  '₹ 10,103',
#  '₹ 10,628',
#  '₹ 7,423',
#  '₹ 7,424',
#  '₹ 7,424',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,425',
#  '₹ 7,740',
#  '₹ 7,741',
#  '',
#  '',
#  '',
#  '₹ 9,210',
#  '₹ 9,362',
#  '₹ 9,657',
#  '₹ 9,788',
#  '₹ 10,008',
#  '₹ 10,050',
#  '₹ 10,103',
#  '₹ 10,103',
#  '₹ 10,628',
#  '₹ 7,423',
#  '₹ 7,424',
#  '₹ 7,424',
#  '',
#  '',
# ...

# %%
print(len(Airline),len(Soruce),len(Destination),len(Departure_time),len(Arrival_time),len(Duration),len(Total_stop),len(Price))
# Out:
# 260 250 260 260 260 260 260 260

# %%
Flight2=pd.DataFrame({})
Flight2["Airline"]=Airline[:250]
Flight2["Source"]=Soruce[:250]
Flight2["Destination"]=Destination[:250]
Flight2["Departure_time"]=Departure_time[:250]
Flight2["Arrival_time"]=Arrival_time[:250]
Flight2["Duration"]=Duration[:250]
Flight2["Total_stop"]=Total_stop[:250]
Flight2["Price"]=Price[:250]
Flight2[:250]
# Out:
#       Airline     Source Destination Departure_time Arrival_time   Duration  \
# 0     AirAsia  New Delhi   Bengaluru          04:55        15:50  10 h 55 m
# 1    Go First  New Delhi   Bengaluru          06:05        08:40  02 h 35 m
# 2    Go First  New Delhi   Bengaluru          09:00        16:25  07 h 25 m
# 3              New Delhi
# 4              New Delhi
# ..        ...        ...         ...            ...          ...        ...
# 245  Spicejet  New Delhi   Bengaluru          18:25        21:10  26 h 45 m
# 246  Spicejet  New Delhi   Bengaluru          05:35        08:05  02 h 30 m
# 247   AirAsia  New Delhi   Bengaluru          21:00        11:35  14 h 35 m
# 248            New Delhi
# 249            New Delhi
#
#              Total_stop    Price
# 0      1 stop via Kochi  ₹ 7,423
# 1              Non stop  ₹ 7,424
# 2    1 stop via Lucknow  ₹ 7,424
# 3
# 4
# ..                  ...      ...
# 245  1 stop via Chennai  ₹ 7,425
# 246            Non stop  ₹ 7,740
# ...

# %%
url='https://www.yatra.com/'
driver.get(url)

# %%
search_button = driver.find_element_by_id('BE_flight_flsearch_btn')
search_button.click()

# %%
Airline=[]
Source=[]
Destination=[]
Departure_time=[]
Arrival_time=[]
Duration=[]
Total_stop=[]
Price=[]

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//span[@class = 'i-b text ellipsis']"):
        Airline.append(j.text)
Airline
# Out:
# ['Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//p[@title = 'New Delhi']"):
        Soruce.append(j.text)
Soruce
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//p[@title = 'Mumbai']"):
        Destination.append(j.text)
Destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//div[@class = 'i-b pr']"):
        Departure_time.append(j.text)
Departure_time
# Out:
# ['22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
#  '06:20',
#  '04:45',
#  '11:20',
#  '04:25',
#  '01:05',
#  '08:45',
#  '08:10',
#  '07:30',
#  '06:35',
#  '09:30',
#  '08:50',
#  '18:55',
#  '23:15',
#  '10:45',
#  '05:15',
#  '09:30',
#  '06:00',
#  '22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
#  '06:20',
#  '04:45',
#  '11:20',
#  '04:25',
#  '01:05',
#  '08:45',
#  '08:10',
#  '07:30',
#  '06:35',
#  '09:30',
#  '08:50',
#  '18:55',
#  '23:15',
#  '10:45',
#  '05:15',
#  '09:30',
#  '06:00',
#  '22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
#  '06:20',
#  '04:45',
#  '11:20',
#  '04:25',
#  '01:05',
#  '08:45',
#  '08:10',
#  '07:30',
#  '06:35',
#  '09:30',
#  '08:50',
#  '18:55',
#  '23:15',
#  '10:45',
#  '05:15',
#  '09:30',
#  '06:00',
#  '22:10',
#  '06:00',
#  '08:00',
#  '02:00',
#  '09:00',
#  '06:30',
#  '07:15',
#  '07:20',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//p[@class = 'bold fs-15 mb-2 pr time']"):
        Arrival_time.append(j.text)
Arrival_time
# Out:
# ['12:25\n+ 1 day',
#  '08:10',
#  '10:10',
#  '04:15',
#  '15:45',
#  '08:40',
#  '09:25',
#  '09:35',
#  '08:40',
#  '07:10',
#  '18:00',
#  '06:35',
#  '03:20',
#  '11:05',
#  '10:20',
#  '09:45',
#  '10:15',
#  '11:45',
#  '11:10',
#  '21:05',
#  '01:25\n+ 1 day',
#  '13:05',
#  '10:05',
#  '11:35',
#  '10:40',
#  '12:25\n+ 1 day',
#  '08:10',
#  '10:10',
#  '04:15',
#  '15:45',
#  '08:40',
#  '09:25',
#  '09:35',
#  '08:40',
#  '07:10',
#  '18:00',
#  '06:35',
#  '03:20',
#  '11:05',
#  '10:20',
#  '09:45',
#  '10:15',
#  '11:45',
#  '11:10',
#  '21:05',
#  '01:25\n+ 1 day',
#  '13:05',
#  '10:05',
#  '11:35',
#  '10:40',
#  '12:25\n+ 1 day',
#  '08:10',
#  '10:10',
#  '04:15',
#  '15:45',
#  '08:40',
#  '09:25',
#  '09:35',
#  '08:40',
#  '07:10',
#  '18:00',
#  '06:35',
#  '03:20',
#  '11:05',
#  '10:20',
#  '09:45',
#  '10:15',
#  '11:45',
#  '11:10',
#  '21:05',
#  '01:25\n+ 1 day',
#  '13:05',
#  '10:05',
#  '11:35',
#  '10:40',
#  '12:25\n+ 1 day',
#  '08:10',
#  '10:10',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//p[@class = 'fs-12 bold du mb-2']"):
        Duration.append(j.text)
Duration
# Out:
# ['14h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '6h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '6h 40m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '3h 40m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 20m',
#  '4h 50m',
#  '2h 05m',
#  '4h 40m',
#  '14h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '6h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '6h 40m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '3h 40m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 20m',
#  '4h 50m',
#  '2h 05m',
#  '4h 40m',
#  '14h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '6h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '6h 40m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '3h 40m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 10m',
#  '2h 20m',
#  '4h 50m',
#  '2h 05m',
#  '4h 40m',
#  '14h 15m',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//span[@class = 'dotted-borderbtm']"):
        Total_stop.append(j.text)
Total_stop
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
for i in range(0,20):
    for j in driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']"):
        Price.append(j.text)
Price
# Out:
# ['5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,139',
#  '6,585',
#  '6,795',
#  '7,110',
#  '7,530',
#  '8,264',
#  '8,370',
#  '8,790',
#  '9,104',
#  '9,420',
#  '9,420',
#  '9,420',
#  '9,525',
#  '9,761',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,139',
#  '6,585',
#  '6,795',
#  '7,110',
#  '7,530',
#  '8,264',
#  '8,370',
#  '8,790',
#  '9,104',
#  '9,420',
#  '9,420',
#  '9,420',
#  '9,525',
#  '9,761',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,139',
#  '6,585',
#  '6,795',
#  '7,110',
#  '7,530',
#  '8,264',
#  '8,370',
#  '8,790',
#  '9,104',
#  '9,420',
#  '9,420',
#  '9,420',
#  '9,525',
#  '9,761',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
# ...

# %%
print(len(Airline),len(Soruce),len(Destination),len(Departure_time),len(Arrival_time),len(Duration),len(Total_stop),len(Price))
# Out:
# 500 1250 500 500 500 500 720 500

# %%
Flight3=pd.DataFrame({})
Flight3["Airline"]=Airline
Flight3["Source"]=Soruce[:500]
Flight3["Destination"]=Destination
Flight3["Departure_time"]=Departure_time
Flight3["Arrival_time"]=Arrival_time
Flight3["Duration"]=Duration
Flight3["Total_stop"]=Total_stop[:500]
Flight3["Price"]=Price
Flight3
# Out:
#       Airline     Source Destination Departure_time    Arrival_time Duration  \
# 0    Air Asia  New Delhi      Mumbai          22:10  12:25\n+ 1 day  14h 15m
# 1    Go First  New Delhi      Mumbai          06:00           08:10   2h 10m
# 2    Go First  New Delhi      Mumbai          08:00           10:10   2h 10m
# 3    Go First  New Delhi      Mumbai          02:00           04:15   2h 15m
# 4    Go First  New Delhi      Mumbai          09:00           15:45   6h 45m
# ..        ...        ...         ...            ...             ...      ...
# 495    IndiGo  New Delhi      Mumbai          23:15  01:25\n+ 1 day   2h 10m
# 496    IndiGo  New Delhi      Mumbai          10:45           13:05   2h 20m
# 497    IndiGo  New Delhi      Mumbai          05:15           10:05   4h 50m
# 498   Vistara  New Delhi      Mumbai          09:30           11:35   2h 05m
# 499  Go First  New Delhi      Mumbai          06:00           10:40   4h 40m
#
#     Total_stop  Price
# ...

# %%
df = pd.concat([Flight1, Flight2, Flight3])

# %%
df
# Out:
#       Airline     Soruce Destination Departure_time    Arrival_time Duration  \
# 0    Air Asia  New Delhi      Mumbai          22:10  12:25\n+ 1 day  14h 15m
# 1    Go First  New Delhi      Mumbai          06:00           08:10   2h 10m
# 2    Go First  New Delhi      Mumbai          08:00           10:10   2h 10m
# 3    Go First  New Delhi      Mumbai          02:00           04:15   2h 15m
# 4    Go First  New Delhi      Mumbai          09:00           15:45   6h 45m
# ..        ...        ...         ...            ...             ...      ...
# 495    IndiGo        NaN      Mumbai          23:15  01:25\n+ 1 day   2h 10m
# 496    IndiGo        NaN      Mumbai          10:45           13:05   2h 20m
# 497    IndiGo        NaN      Mumbai          05:15           10:05   4h 50m
# 498   Vistara        NaN      Mumbai          09:30           11:35   2h 05m
# 499  Go First        NaN      Mumbai          06:00           10:40   4h 40m
#
#     Total_stop  Price     Source
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 930 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         930 non-null    object
#  1   Soruce          180 non-null    object
#  2   Destination     930 non-null    object
#  3   Departure_time  930 non-null    object
#  4   Arrival_time    930 non-null    object
#  5   Duration        930 non-null    object
#  6   Total_stop      930 non-null    object
#  7   Price           930 non-null    object
#  8   Source          750 non-null    object
# dtypes: object(9)
# memory usage: 72.7+ KB

# %%
df.describe()
# Out:
#        Airline     Soruce Destination Departure_time Arrival_time Duration  \
# count      930        180         930            930          930      930
# unique       8          1           3             40           38       25
# top     IndiGo  New Delhi      Mumbai                               2h 10m
# freq       344        180         680             79           79      218
#
#        Total_stop  Price     Source
# count         930    930        750
# unique         10     29          1
# top        1 Stop  5,955  New Delhi
# freq          680    162        750
