# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://internshala.com/fresher-jobs")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
job_name = soup.find_all("div" , class_ = "heading_4_5 profile")

# %%
job_name = [i.get_text() for i in job_name]

# %%
Location = soup.find_all("a" , class_ = "link_display_like_text")

# %%
Location = [i.get_text() for i in Location]

# %%
start_date = soup.find_all("div" , class_ = "item_body")

# %%
start_date = [i.get_text() for i in start_date]

# %%
count = 0
starts = []
salary = []
apply_by = []
for i in start_date:
    if count % 3 == 0:
        starts.append(i)
    count = count+1
for l in start_date:
    if count % 3 == 1:
        salary.append(l)
    count = count+1
for k in start_date:
    if count % 3 == 2:
        apply_by.append(k)
    count += 1

# %%
company_name = soup.find_all("a" , class_ = "link_display_like_text")

# %%
apply_by
# Out:
# ["19 Jul' 21",
#  "19 Jul' 21",
#  "19 Jul' 21",
#  "19 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "16 Jul' 21",
#  "17 Jul' 21",
#  "16 Jul' 21",
#  "16 Jul' 21",
#  "17 Jul' 21",
#  "16 Jul' 21",
#  "16 Jul' 21",
#  "16 Jul' 21",
#  "15 Jul' 21",
#  "15 Jul' 21",
#  "15 Jul' 21",
#  "14 Jul' 21",
#  "14 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21",
#  "14 Jul' 21",
#  "15 Jul' 21",
#  "10 Jul' 21",
#  "10 Jul' 21",
#  "9 Jul' 21",
#  "9 Jul' 21"]

# %%
salary
# Out:
# ['\n  3 - 4 LPA                                                    ',
#  '\n  3 - 3.5 LPA                                                    ',
#  '\n  3 LPA                                                    ',
#  '\n  3 - 6.5 LPA                                                    ',
#  '\n  6 - 7 LPA                                                    ',
#  '\n  3 - 5 LPA                                                    ',
#  '\n  4 LPA                                                    ',
#  '\n  3 - 3.5 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ',
#  '\n  4.5 - 7 LPA                                                    ',
#  '\n  4.99 - 5 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ',
#  '\n  3 - 3.6 LPA                                                    ',
#  '\n  3 - 4.5 LPA                                                    ',
#  '\n  3 - 3.6 LPA                                                    ',
#  '\n  3 LPA                                                    ',
#  '\n  3 - 3.25 LPA                                                    ',
#  '\n  3 LPA                                                    ',
#  '\n  3 - 3.5 LPA                                                    ',
#  '\n  3 LPA                                                    ',
#  '\n  3 - 3.5 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ',
#  '\n  3 - 5 LPA                                                    ',
#  '\n  9 LPA                                                    ',
#  '\n  3.75 LPA                                                    ',
#  '\n  4 - 4.2 LPA                                                    ',
#  '\n  3 LPA                                                    ',
#  '\n  3.5 - 5 LPA                                                    ',
#  '\n  3.6 - 10 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ',
#  '\n  3.3 - 4 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ',
#  '\n  3 - 6 LPA                                                    ',
#  '\n  4.5 - 5.25 LPA                                                    ',
#  '\n  3 - 5 LPA                                                    ',
#  '\n  3 - 5 LPA                                                    ',
#  '\n  4 - 5 LPA                                                    ',
#  '\n  3 LPA                                                    ',
#  '\n  3 - 4 LPA                                                    ']

# %%
starts
# Out:
# ['\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ',
#  '\nStarts\xa0Immediately\n                        ']

# %%
import pandas as pd
job = pd.DataFrame({})
job["job name"] = job_name
job["start date"] = starts
job["company name"] = company_name
job["salary"] = salary
job["apply by"] = apply_by
job["location"] = Location

# %%
job
# Out:
#                                              job name  \
# 0                                    \nWeb Developer
# 1                        \nSoftware Engineer Trainee
# 2   \nBusiness Development Specialist (Sales & Mar...
# 3                   \nBusiness Development Executive
# 4                    \nAssociate Front End Developer
# 5                        \nCorporate Sales Executive
# 6   \nAssociate Software Developer (Full-Stack - R...
# 7                 \nCustomer Relationship Specialist
# 8                      \nAssociate Editor Engagement
# 9                  \nManagement Consultant Associate
# 10                         \nWeb Analytics Developer
# 11           \nJunior Social Media Marketing Manager
# 12         \nJunior Social Media Marketing Associate
# 13  \nBusiness Development Manager (Digital Market...
# 14                  \nBusiness Development Executive
# 15                                      \nAccountant
# 16                              \nResearch Associate
# 17       \nAssistant Coordinator - Tender Department
# 18  \nCustomer Relationship Manager (Publishing Co...
# 19                 \nExecutive Assistant To Director
# 20                     \nLearning Consultant - Sales
# 21                       \nSchool/Teacher Consultant
# 22                                \nJunior Recruiter
# 23                              \nSoftware Developer
# 24   \nBusiness Development Executive (Inside Sales)
# 25                                   \nWeb Developer
# 26                                 \nOrder Processor
# 27                            \nFull Stack Developer
# 28                    \nAssociate Software Developer
# 29                               \nReactjs Developer
# 30                            \nFull Stack Developer
# 31                  \nBusiness Development Executive
# 32                       \nCorporate Sales Associate
# 33                          \nInside Sales Associate
# 34                            \nMobile App Developer
# 35                     \nJunior MERN Stack Developer
# 36                    \nEducation Innovation Manager
# 37                    \nGeneral Management Associate
# 38         \nContent & E-commerce Management Trainee
# 39                               \nSoftware Engineer
#
#                                         start date  \
# 0   \nStarts Immediately\n
# 1   \nStarts Immediately\n
# 2   \nStarts Immediately\n
# 3   \nStarts Immediately\n
# 4   \nStarts Immediately\n
# 5   \nStarts Immediately\n
# 6   \nStarts Immediately\n
# 7   \nStarts Immediately\n
# 8   \nStarts Immediately\n
# 9   \nStarts Immediately\n
# 10  \nStarts Immediately\n
# 11  \nStarts Immediately\n
# 12  \nStarts Immediately\n
# 13  \nStarts Immediately\n
# 14  \nStarts Immediately\n
# 15  \nStarts Immediately\n
# 16  \nStarts Immediately\n
# 17  \nStarts Immediately\n
# 18  \nStarts Immediately\n
# 19  \nStarts Immediately\n
# 20  \nStarts Immediately\n
# 21  \nStarts Immediately\n
# 22  \nStarts Immediately\n
# 23  \nStarts Immediately\n
# 24  \nStarts Immediately\n
# 25  \nStarts Immediately\n
# 26  \nStarts Immediately\n
# 27  \nStarts Immediately\n
# 28  \nStarts Immediately\n
# 29  \nStarts Immediately\n
# 30  \nStarts Immediately\n
# 31  \nStarts Immediately\n
# 32  \nStarts Immediately\n
# 33  \nStarts Immediately\n
# 34  \nStarts Immediately\n
# 35  \nStarts Immediately\n
# 36  \nStarts Immediately\n
# 37  \nStarts Immediately\n
# 38  \nStarts Immediately\n
# 39  \nStarts Immediately\n
#
#                                          company name  \
# 0   [\n                        Manufac Analytics P...
# 1   [\n                        Swabhav Techlabs   ...
# 2   [\n                        Claraeon Learning P...
# 3   [\n                        Picostone          ...
# 4   [\n                        AIMonk Labs Technol...
# 5   [\n                        369 Zoss Waters    ...
# 6   [\n                        SleekSky LLC       ...
# 7   [\n                        InPhase Power Techn...
# 8   [\n                        Cactus Communicatio...
# 9   [\n                        StrategyCo.Global  ...
# 10  [\n                        DataVinci Private L...
# 11  [\n                        The Test Tribe     ...
# 12  [\n                        Glu Studios        ...
# 13  [\n                        Graygraph Technolog...
# 14  [\n                        BookLeaf Publishing...
# 15  [\n                        Ravi Ladia & Co    ...
# 16  [\n                        Market Vistas Consu...
# 17  [\n                        Global Source Tradi...
# 18  [\n                        Blue Rose Publisher...
# 19  [\n                        Best Roadways Limit...
# 20  [\n                        Geekster           ...
# 21  [\n                        InfyBytes AI Labs P...
# 22  [\n                        Radish Consultants ...
# 23  [\n                        Moxie.xyz          ...
# 24  [\n                        GREedge            ...
# 25  [\n                        Fullmoon Outdoor We...
# 26  [\n                        InspectHOA         ...
# 27  [\n                        Nikulsan Technologi...
# 28  [\n                        IQGateway          ...
# 29  [\n                        Startxlabs Technolo...
# 30  [\n                        RavGins Internation...
# 31  [\n                        Varenyam Placements...
# 32  [\n                        HealthPlix Technolo...
# 33  [\n                        Wizklub Learning   ...
# 34  [\n                        Fusion Engineering ...
# 35  [\n                        DeepThought Edutech...
# 36  [\n                        DeepThought Edutech...
# 37  [\n                        Redwood Algorithms ...
# 38  [\n                        Blooprint Ecom Cons...
# 39  [\n                        QuikieApps         ...
#
#                                                salary    apply by  \
# 0   \n  3 - 4 LPA                                 ...  19 Jul' 21
# 1   \n  3 - 3.5 LPA                               ...  19 Jul' 21
# 2   \n  3 LPA                                     ...  19 Jul' 21
# 3   \n  3 - 6.5 LPA                               ...  19 Jul' 21
# 4   \n  6 - 7 LPA                                 ...  18 Jul' 21
# 5   \n  3 - 5 LPA                                 ...  18 Jul' 21
# 6   \n  4 LPA                                     ...  18 Jul' 21
# 7   \n  3 - 3.5 LPA                               ...  18 Jul' 21
# 8   \n  3 - 4 LPA                                 ...  18 Jul' 21
# 9   \n  4.5 - 7 LPA                               ...  18 Jul' 21
# 10  \n  4.99 - 5 LPA                              ...  17 Jul' 21
# 11  \n  3 - 4 LPA                                 ...  17 Jul' 21
# 12  \n  3 - 3.6 LPA                               ...  17 Jul' 21
# 13  \n  3 - 4.5 LPA                               ...  17 Jul' 21
# 14  \n  3 - 3.6 LPA                               ...  17 Jul' 21
# 15  \n  3 LPA                                     ...  16 Jul' 21
# 16  \n  3 - 3.25 LPA                              ...  17 Jul' 21
# 17  \n  3 LPA                                     ...  16 Jul' 21
# 18  \n  3 - 3.5 LPA                               ...  16 Jul' 21
# 19  \n  3 LPA                                     ...  17 Jul' 21
# 20  \n  3 - 3.5 LPA                               ...  16 Jul' 21
# 21  \n  3 - 4 LPA                                 ...  16 Jul' 21
# 22  \n  3 - 5 LPA                                 ...  16 Jul' 21
# 23  \n  9 LPA                                     ...  15 Jul' 21
# 24  \n  3.75 LPA                                  ...  15 Jul' 21
# 25  \n  4 - 4.2 LPA                               ...  15 Jul' 21
# 26  \n  3 LPA                                     ...  14 Jul' 21
# 27  \n  3.5 - 5 LPA                               ...  14 Jul' 21
# 28  \n  3.6 - 10 LPA                              ...  11 Jul' 21
# 29  \n  3 - 4 LPA                                 ...  11 Jul' 21
# 30  \n  3.3 - 4 LPA                               ...  11 Jul' 21
# 31  \n  3 - 4 LPA                                 ...  11 Jul' 21
# 32  \n  3 - 4 LPA                                 ...  11 Jul' 21
# 33  \n  3 - 6 LPA                                 ...  11 Jul' 21
# 34  \n  4.5 - 5.25 LPA                            ...  14 Jul' 21
# 35  \n  3 - 5 LPA                                 ...  15 Jul' 21
# 36  \n  3 - 5 LPA                                 ...  10 Jul' 21
# 37  \n  4 - 5 LPA                                 ...  10 Jul' 21
# 38  \n  3 LPA                                     ...   9 Jul' 21
# 39  \n  3 - 4 LPA                                 ...   9 Jul' 21
#
#                                              location
# 0   \n                        Manufac Analytics Pr...
# 1   \n                        Swabhav Techlabs    ...
# 2   \n                        Claraeon Learning Pr...
# 3   \n                        Picostone           ...
# 4   \n                        AIMonk Labs Technolo...
# 5   \n                        369 Zoss Waters     ...
# 6   \n                        SleekSky LLC        ...
# 7   \n                        InPhase Power Techno...
# 8   \n                        Cactus Communication...
# 9   \n                        StrategyCo.Global   ...
# 10  \n                        DataVinci Private Li...
# 11  \n                        The Test Tribe      ...
# 12  \n                        Glu Studios         ...
# 13  \n                        Graygraph Technologi...
# 14  \n                        BookLeaf Publishing ...
# 15  \n                        Ravi Ladia & Co     ...
# 16  \n                        Market Vistas Consum...
# 17  \n                        Global Source Tradin...
# 18  \n                        Blue Rose Publishers...
# 19  \n                        Best Roadways Limite...
# 20  \n                        Geekster            ...
# 21  \n                        InfyBytes AI Labs Pr...
# 22  \n                        Radish Consultants P...
# 23  \n                        Moxie.xyz           ...
# 24  \n                        GREedge             ...
# 25  \n                        Fullmoon Outdoor Web...
# 26  \n                        InspectHOA          ...
# 27  \n                        Nikulsan Technologie...
# 28  \n                        IQGateway           ...
# 29  \n                        Startxlabs Technolog...
# 30  \n                        RavGins Internationa...
# 31  \n                        Varenyam Placements ...
# 32  \n                        HealthPlix Technolog...
# 33  \n                        Wizklub Learning    ...
# 34  \n                        Fusion Engineering  ...
# 35  \n                        DeepThought Edutech ...
# 36  \n                        DeepThought Edutech ...
# 37  \n                        Redwood Algorithms  ...
# 38  \n                        Blooprint Ecom Consu...
# 39  \n                        QuikieApps          ...
