# %% [markdown]
# # getting headline from wikiepedia

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
soup = BeautifulSoup(page.content, 'html.parser')
head = soup.find_all("span" , class_ = "mw-headline")
data = [i.get_text() for i in head]
data
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %% [markdown]
# # IMBD top 100 rated indian movies

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.imdb.com/list/ls009997493/")
soup = BeautifulSoup(page.content, 'html.parser')
data = soup.find_all("h3" , class_ = "lister-item-header")
data = [i.get_text() for i in data]
data
# Out:
# ['\n1.\nRang De Basanti\n(2006)\n',
#  '\n2.\n3 Idiots\n(2009)\n',
#  '\n3.\nTaare Zameen Par\n(2007)\n',
#  '\n4.\nDil Chahta Hai\n(2001)\n',
#  '\n5.\nSwades: We, the People\n(2004)\n',
#  '\n6.\nLagaan: Once Upon a Time in India\n(2001)\n',
#  '\n7.\nGangs of Wasseypur\n(2012)\n',
#  '\n8.\nBarfi!\n(2012)\n',
#  '\n9.\nAnand\n(1971)\n',
#  '\n10.\nMunna Bhai M.B.B.S.\n(2003)\n',
#  '\n11.\nA Wednesday\n(2008)\n',
#  '\n12.\nAndaz Apna Apna\n(1994)\n',
#  '\n13.\nSholay\n(1975)\n',
#  '\n14.\nBhaag Milkha Bhaag\n(2013)\n',
#  '\n15.\nHera Pheri\n(2000)\n',
#  '\n16.\nUdaan\n(2010)\n',
#  '\n17.\nKahaani\n(2012)\n',
#  '\n18.\nBlack\n(2005)\n',
#  '\n19.\nChak De! India\n(2007)\n',
#  '\n20.\nKhosla Ka Ghosla!\n(2006)\n',
#  '\n21.\nJo Jeeta Wohi Sikandar\n(1992)\n',
#  '\n22.\nZindagi Na Milegi Dobara\n(2011)\n',
#  '\n23.\nPaan Singh Tomar\n(2012)\n',
#  '\n24.\nDilwale Dulhania Le Jayenge\n(1995)\n',
#  '\n25.\nOmkara\n(2006)\n',
#  '\n26.\nLage Raho Munna Bhai\n(2006)\n',
#  '\n27.\nIqbal\n(2005)\n',
#  '\n28.\nThe Lunchbox\n(2013)\n',
#  '\n29.\nBlack Friday\n(2004)\n',
#  '\n30.\nCompany\n(2002)\n',
#  '\n31.\nGolmaal\n(1979)\n',
#  '\n32.\nDev.D\n(2009)\n',
#  '\n33.\nJaane Bhi Do Yaaro\n(1983)\n',
#  '\n34.\nOMG: Oh My God!\n(2012)\n',
#  '\n35.\nMughal-E-Azam\n(1960)\n',
#  '\n36.\nGulaal\n(2009)\n',
#  '\n37.\nDor\n(2006)\n',
#  '\n38.\nJab We Met\n(2007)\n',
#  '\n39.\nPyaasa\n(1957)\n',
#  '\n40.\nThe Legend of Bhagat Singh\n(2002)\n',
#  '\n41.\nMasoom\n(1983)\n',
#  '\n42.\nSalaam Bombay!\n(1988)\n',
#  '\n43.\nSatya\n(1998)\n',
#  '\n44.\nVicky Donor\n(2012)\n',
#  '\n45.\nLakshya\n(2004)\n',
#  '\n46.\nVaastav: The Reality\n(1999)\n',
#  '\n47.\nKal Ho Naa Ho\n(2003)\n',
#  '\n48.\nOye Lucky! Lucky Oye!\n(2008)\n',
#  '\n49.\nSarfarosh\n(1999)\n',
#  '\n50.\nGangaajal\n(2003)\n',
#  '\n51.\nAngoor\n(1982)\n',
#  '\n52.\nMadras Cafe\n(2013)\n',
#  '\n53.\nEnglish Vinglish\n(2012)\n',
#  '\n54.\nChupke Chupke\n(1975)\n',
#  '\n55.\nJohnny Gaddaar\n(2007)\n',
#  '\n56.\nMaqbool\n(2003)\n',
#  '\n57.\nHazaaron Khwaishein Aisi\n(2003)\n',
#  '\n58.\nRock On!!\n(2008)\n',
#  '\n59.\nDon\n(1978)\n',
#  '\n60.\nChhoti Si Baat\n(1976)\n',
#  '\n61.\nGuide\n(1965)\n',
#  '\n62.\nRaanjhanaa\n(2013)\n',
#  '\n63.\nDeewaar\n(1975)\n',
#  '\n64.\nSpecial Chabbis\n(2013)\n',
#  '\n65.\nPadosan\n(1968)\n',
#  '\n66.\nMumbai Meri Jaan\n(2008)\n',
#  '\n67.\nAb Tak Chhappan\n(2004)\n',
#  '\n68.\nKai po che!\n(2013)\n',
#  '\n69.\nAwaara\n(1951)\n',
#  '\n70.\nShree 420\n(1955)\n',
#  '\n71.\nEarth\n(1998)\n',
#  '\n72.\nGunda\n(1998)\n',
#  '\n73.\nParinda\n(1989)\n',
#  '\n74.\nDasvidaniya\n(2008)\n',
#  '\n75.\nHey Ram\n(2000)\n',
#  '\n76.\nPinjar: Beyond Boundaries...\n(2003)\n',
#  '\n77.\nSocha Na Tha\n(2005)\n',
#  '\n78.\nGuru\n(2007)\n',
#  '\n79.\nBawarchi\n(1972)\n',
#  '\n80.\nManorama: Six Feet Under\n(2007)\n',
#  '\n81.\nMr. India\n(1987)\n',
#  '\n82.\nAamir\n(2008)\n',
#  '\n83.\nZakhm\n(1998)\n',
#  '\n84.\nWater\n(I) (2005)\n',
#  '\n85.\nStanley Ka Dabba\n(2011)\n',
#  '\n86.\nAgneepath\n(1990)\n',
#  '\n87.\nMy Name Is Khan\n(2010)\n',
#  '\n88.\nQayamat Se Qayamat Tak\n(1988)\n',
#  '\n89.\n3 Deewarein\n(2003)\n',
#  '\n90.\nAbhimaan\n(1973)\n',
#  '\n91.\nSarkar\n(2005)\n',
#  '\n92.\nBheja Fry\n(2007)\n',
#  '\n93.\nMother India\n(1957)\n',
#  '\n94.\nJaane Tu... Ya Jaane Na\n(2008)\n',
#  '\n95.\nDelhi Belly\n(2011)\n',
#  '\n96.\nWake Up Sid\n(2009)\n',
#  '\n97.\nRangeela\n(1995)\n',
#  '\n98.\nShatranj Ke Khilari\n(1977)\n',
#  '\n99.\nPyaar Ka Punchnama\n(2011)\n',
#  '\n100.\nEk Hasina Thi\n(2004)\n']

# %% [markdown]
# # IMBD top 100 rated movies

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc")
soup = BeautifulSoup(page.content, 'html.parser')
fifty = soup.find_all("h3" , class_ = "lister-item-header")
page = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&start=51&ref_=adv_nxt")
soup = BeautifulSoup(page.content, 'html.parser')
hundred = soup.find_all("h3", class_ = "lister-item-header")
hundred = [i.get_text() for i in hundred]
fifty = [i.get_text() for i in fifty]
import pandas as pd
game = pd.DataFrame({})
game["first fifty"] = fifty
game["the rest"] = hundred
game
# Out:
#                                           first fifty  \
# 0            \n1.\nThe Shawshank Redemption\n(1994)\n
# 1                       \n2.\nThe Godfather\n(1972)\n
# 2                     \n3.\nThe Dark Knight\n(2008)\n
# 3              \n4.\nThe Godfather: Part II\n(1974)\n
# 4                        \n5.\n12 Angry Men\n(1957)\n
# 5   \n6.\nThe Lord of the Rings: The Return of the...
# 6                        \n7.\nPulp Fiction\n(1994)\n
# 7                    \n8.\nSchindler's List\n(1993)\n
# 8                           \n9.\nInception\n(2010)\n
# 9                         \n10.\nFight Club\n(1999)\n
# 10  \n11.\nThe Lord of the Rings: The Fellowship o...
# 11                      \n12.\nForrest Gump\n(1994)\n
# 12   \n13.\nIl buono, il brutto, il cattivo\n(1966)\n
# 13  \n14.\nThe Lord of the Rings: The Two Towers\n...
# 14                        \n15.\nThe Matrix\n(1999)\n
# 15                        \n16.\nGoodfellas\n(1990)\n
# 16  \n17.\nStar Wars: Episode V - The Empire Strik...
# 17   \n18.\nOne Flew Over the Cuckoo's Nest\n(1975)\n
# 18                      \n19.\nGisaengchung\n(2019)\n
# 19                      \n20.\nInterstellar\n(2014)\n
# 20                    \n21.\nCidade de Deus\n(2002)\n
# 21     \n22.\nSen to Chihiro no kamikakushi\n(2001)\n
# 22               \n23.\nSaving Private Ryan\n(1998)\n
# 23                    \n24.\nThe Green Mile\n(1999)\n
# 24                   \n25.\nLa vita è bella\n(1997)\n
# 25                             \n26.\nSe7en\n(1995)\n
# 26          \n27.\nThe Silence of the Lambs\n(1991)\n
# 27                         \n28.\nStar Wars\n(1977)\n
# 28                           \n29.\nSeppuku\n(1962)\n
# 29                   \n30.\nPather Panchali\n(1955)\n
# 30              \n31.\nShichinin no samurai\n(1954)\n
# 31             \n32.\nIt's a Wonderful Life\n(1946)\n
# 32                          \n33.\nWhiplash\n(2014)\n
# 33                  \n34.\nThe Intouchables\n(2011)\n
# 34                      \n35.\nThe Prestige\n(2006)\n
# 35                      \n36.\nThe Departed\n(2006)\n
# 36                       \n37.\nThe Pianist\n(2002)\n
# 37                         \n38.\nGladiator\n(2000)\n
# 38                \n39.\nAmerican History X\n(1998)\n
# 39                \n40.\nThe Usual Suspects\n(1995)\n
# 40                              \n41.\nLéon\n(1994)\n
# 41                     \n42.\nThe Lion King\n(1994)\n
# 42        \n43.\nTerminator 2: Judgment Day\n(1991)\n
# 43             \n44.\nNuovo Cinema Paradiso\n(1988)\n
# 44                    \n45.\nHotaru no haka\n(1988)\n
# 45                \n46.\nBack to the Future\n(1985)\n
# 46      \n47.\nOnce Upon a Time in the West\n(1968)\n
# 47                            \n48.\nPsycho\n(1960)\n
# 48                       \n49.\nRear Window\n(1954)\n
# 49                        \n50.\nCasablanca\n(1942)\n
#
#                                              the rest
# 0                       \n51.\nModern Times\n(1936)\n
# 1                        \n52.\nCity Lights\n(1931)\n
# 2                           \n53.\nHamilton\n(2020)\n
# 3                         \n54.\nCapharnaüm\n(2018)\n
# 4                              \n55.\nJoker\n(2019)\n
# 5                     \n56.\nKimi no na wa.\n(2016)\n
# 6   \n57.\nSpider-Man: Into the Spider-Verse\n(201...
# 7                  \n58.\nAvengers: Endgame\n(2019)\n
# 8             \n59.\nAvengers: Infinity War\n(2018)\n
# 9                           \n60.\nCoco\n(I) (2017)\n
# 10                  \n61.\nDjango Unchained\n(2012)\n
# 11             \n62.\nThe Dark Knight Rises\n(2012)\n
# 12                          \n63.\n3 Idiots\n(2009)\n
# 13                  \n64.\nTaare Zameen Par\n(2007)\n
# 14                            \n65.\nWALL·E\n(2008)\n
# 15               \n66.\nThe Lives of Others\n(2006)\n
# 16                          \n67.\nOldeuboi\n(2003)\n
# 17                           \n68.\nMemento\n(2000)\n
# 18                     \n69.\nMononoke-hime\n(1997)\n
# 19       \n70.\nOnce Upon a Time in America\n(1984)\n
# 20           \n71.\nRaiders of the Lost Ark\n(1981)\n
# 21                       \n72.\nThe Shining\n(1980)\n
# 22                    \n73.\nApocalypse Now\n(1979)\n
# 23                             \n74.\nAlien\n(1979)\n
# 24                 \n75.\nTengoku to jigoku\n(1963)\n
# 25  \n76.\nDr. Strangelove or: How I Learned to St...
# 26       \n77.\nWitness for the Prosecution\n(1957)\n
# 27                    \n78.\nPaths of Glory\n(1957)\n
# 28                      \n79.\nSunset Blvd.\n(1950)\n
# 29                \n80.\nThe Great Dictator\n(1940)\n
# 30                            \n81.\nJagten\n(2012)\n
# 31              \n82.\nInglourious Basterds\n(2009)\n
# 32  \n83.\nEternal Sunshine of the Spotless Mind\n...
# 33               \n84.\nRequiem for a Dream\n(2000)\n
# 34                   \n85.\nAmerican Beauty\n(1999)\n
# 35                 \n86.\nGood Will Hunting\n(1997)\n
# 36                         \n87.\nToy Story\n(1995)\n
# 37                        \n88.\nBraveheart\n(1995)\n
# 38                    \n89.\nReservoir Dogs\n(1992)\n
# 39                      \n90.\nIdi i smotri\n(1985)\n
# 40                            \n91.\nAliens\n(1986)\n
# 41                           \n92.\nAmadeus\n(1984)\n
# 42  \n93.\nStar Wars: Episode VI - Return of the J...
# 43                          \n94.\nDas Boot\n(1981)\n
# 44             \n95.\n2001: A Space Odyssey\n(1968)\n
# 45                \n96.\nNorth by Northwest\n(1959)\n
# 46                           \n97.\nVertigo\n(1958)\n
# 47               \n98.\nSingin' in the Rain\n(1952)\n
# 48                      \n99.\nCitizen Kane\n(1941)\n
# 49  \n100.\nM - Eine Stadt sucht einen Mörder\n(19...

# %% [markdown]
# # Internshala fresher jobs

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://internshala.com/fresher-jobs")
soup = BeautifulSoup(page.content, 'html.parser')
job_name = soup.find_all("div" , class_ = "heading_4_5 profile")
job_name = [i.get_text() for i in job_name]
Location = soup.find_all("a" , class_ = "link_display_like_text")
Location = [i.get_text() for i in Location]
start_date = soup.find_all("div" , class_ = "item_body")
start_date = [i.get_text() for i in start_date]
count = 0
starts = []
salary = []
apply_by = []
for i in start_date:
    if count % 3 == 0:
        starts.append(i)
    count = count+1
for l in start_date:
    if count % 3 == 1:
        salary.append(l)
    count = count+1
for k in start_date:
    if count % 3 == 2:
        apply_by.append(k)
    count += 1
company_name = soup.find_all("a" , class_ = "link_display_like_text")
import pandas as pd
job = pd.DataFrame({})
job["job name"] = job_name
job["start date"] = starts
job["company name"] = company_name
job["salary"] = salary
job["apply by"] = apply_by
job["location"] = Location
job
# Out:
#                                              job name  \
# 0                      \nAssociate Creative Designer
# 1                         \nAssociate Content Writer
# 2                   \nHuman Resources (HR) Executive
# 3                                \nSoftware Engineer
# 4                             \nSalesforce Developer
# 5                             \nFull Stack Developer
# 6                  \nBusiness Development Specialist
# 7                     \nAssociate Software Developer
# 8                         \nAssociate UI/UX Designer
# 9           \nBusiness Development Associate (Sales)
# 10                \nReceptionist And Billing Manager
# 11         \nNode.js Backend Developer (AWS/GCP/API)
# 12                  \nBusiness Development Executive
# 13                              \nSoftware Developer
# 14  \nManagement Trainee - Assistant Category Mana...
# 15                 \nAccount Executive - Field Sales
# 16                               \nSoftware Engineer
# 17                    \nAssociate Software Developer
# 18          \nSocial Media Strategist And Copywriter
# 19              \nLevel 1 Technical Support Engineer
# 20                    \nAssociate Software Developer
# 21                            \nAccounting Assistant
# 22                               \nSoftware Engineer
# 23                    \nBusiness Development Manager
# 24                  \nBusiness Development Executive
# 25                 \nProduct Developer - Mathematics
# 26                \nSales Development Representative
# 27                             \nFull Stack Engineer
# 28                        \nJunior ReactJS Developer
# 29                               \nMarketing Manager
# 30                     \nProduct Marketing Associate
# 31                        \nAdministration Associate
# 32                    \nAssociate Software Developer
# 33                             \nProject Coordinator
# 34                                   \nWeb Developer
# 35                       \nSoftware Engineer Trainee
# 36  \nBusiness Development Specialist (Sales & Mar...
# 37                  \nBusiness Development Executive
# 38                   \nAssociate Front End Developer
# 39                       \nCorporate Sales Executive
#
#                                         start date  \
# 0   \nStarts Immediately\n
# 1   \nStarts Immediately\n
# 2   \nStarts Immediately\n
# 3   \nStarts Immediately\n
# 4   \nStarts Immediately\n
# 5   \nStarts Immediately\n
# 6   \nStarts Immediately\n
# 7   \nStarts Immediately\n
# 8   \nStarts Immediately\n
# 9   \nStarts Immediately\n
# 10  \nStarts Immediately\n
# 11  \nStarts Immediately\n
# 12  \nStarts Immediately\n
# 13  \nStarts Immediately\n
# 14  \nStarts Immediately\n
# 15  \nStarts Immediately\n
# 16  \nStarts Immediately\n
# 17  \nStarts Immediately\n
# 18  \nStarts Immediately\n
# 19  \nStarts Immediately\n
# 20  \nStarts Immediately\n
# 21  \nStarts Immediately\n
# 22  \nStarts Immediately\n
# 23  \nStarts Immediately\n
# 24  \nStarts Immediately\n
# 25  \nStarts Immediately\n
# 26  \nStarts Immediately\n
# 27  \nStarts Immediately\n
# 28  \nStarts Immediately\n
# 29  \nStarts Immediately\n
# 30  \nStarts Immediately\n
# 31  \nStarts Immediately\n
# 32  \nStarts Immediately\n
# 33  \nStarts Immediately\n
# 34  \nStarts Immediately\n
# 35  \nStarts Immediately\n
# 36  \nStarts Immediately\n
# 37  \nStarts Immediately\n
# 38  \nStarts Immediately\n
# 39  \nStarts Immediately\n
#
#                                          company name  \
# 0   [\n                        Muskurahat Foundati...
# 1   [\n                        Muskurahat Foundati...
# 2   [\n                        Muskurahat Foundati...
# 3   [\n                        Vaultedge Software ...
# 4   [\n                        Softsensor.ai      ...
# 5   [\n                        ProtonAutoML       ...
# 6   [\n                        ProtonAutoML       ...
# 7   [\n                        RoaDo              ...
# 8   [\n                        RavGins Internation...
# 9   [\n                        Global Sun         ...
# 10  [\n                        Touchstone Partners...
# 11  [\n                        Labellerr By Tensor...
# 12  [\n                        UFaber Edutech     ...
# 13  [\n                        Aptigenz Solutions ...
# 14  [\n                        Noise              ...
# 15  [\n                        RoaDo              ...
# 16  [\n                        CrewKarma          ...
# 17  [\n                        IQGateway          ...
# 18  [\n                        Internshala        ...
# 19  [\n                        Mithi Software Tech...
# 20  [\n                        White Blink        ...
# 21  [\n                        Wono Inc           ...
# 22  [\n                        Wono Inc           ...
# 23  [\n                        Wono Inc           ...
# 24  [\n                        Emertxe Information...
# 25  [\n                        Open Door Education...
# 26  [\n                        Content Beta       ...
# 27  [\n                        Softway Solutions P...
# 28  [\n                        DeepThought Edutech...
# 29  [\n                        Saltoro Coffee Roas...
# 30  [\n                        WebMOBI            ...
# 31  [\n                        Global Sun         ...
# 32  [\n                        Medico Healthcare S...
# 33  [\n                        Edupixels          ...
# 34  [\n                        Manufac Analytics P...
# 35  [\n                        Swabhav Techlabs   ...
# 36  [\n                        Claraeon Learning P...
# 37  [\n                        Picostone          ...
# 38  [\n                        AIMonk Labs Technol...
# 39  [\n                        369 Zoss Waters    ...
#
#                                                salary    apply by  \
# 0   \n  3 - 4 LPA                                 ...  26 Jul' 21
# 1   \n  3 - 4 LPA                                 ...  26 Jul' 21
# 2   \n  3 - 4 LPA                                 ...  26 Jul' 21
# 3   \n  6 - 8 LPA                                 ...  26 Jul' 21
# 4   \n  3 - 5 LPA                                 ...  25 Jul' 21
# 5   \n  3 - 4 LPA                                 ...  25 Jul' 21
# 6   \n  3 - 3.5 LPA                               ...  25 Jul' 21
# 7   \n  4 - 6 LPA                                 ...  25 Jul' 21
# 8   \n  3 - 4 LPA                                 ...  25 Jul' 21
# 9   \n  3 - 4.8 LPA                               ...  25 Jul' 21
# 10  \n  3 - 7 LPA                                 ...  25 Jul' 21
# 11  \n  7 - 10 LPA                                ...  25 Jul' 21
# 12  \n  3 - 5 LPA                                 ...  25 Jul' 21
# 13  \n  3 - 3.2 LPA                               ...  24 Jul' 21
# 14  \n  6 - 10 LPA                                ...  24 Jul' 21
# 15  \n  3.2 - 4 LPA                               ...  25 Jul' 21
# 16  \n  3 - 5 LPA                                 ...  24 Jul' 21
# 17  \n  3.6 - 10 LPA                              ...  24 Jul' 21
# 18  \n  5 - 6.8 LPA                               ...  24 Jul' 21
# 19  \n  3 LPA                                     ...  23 Jul' 21
# 20  \n  3 - 3.6 LPA                               ...  23 Jul' 21
# 21  \n  5.4 - 6.1 LPA                             ...  23 Jul' 21
# 22  \n  5.5 - 6.3 LPA                             ...  23 Jul' 21
# 23  \n  5.2 - 5.8 LPA                             ...  23 Jul' 21
# 24  \n  3 LPA                                     ...  23 Jul' 21
# 25  \n  7 - 8 LPA                                 ...  22 Jul' 21
# 26  \n  3 - 4 LPA                                 ...  22 Jul' 21
# 27  \n  5.5 - 9 LPA                               ...  22 Jul' 21
# 28  \n  3 - 5 LPA                                 ...  22 Jul' 21
# 29  \n  3.2 - 3.5 LPA                             ...  22 Jul' 21
# 30  \n  3 LPA                                     ...  22 Jul' 21
# 31  \n  3 - 3.2 LPA                               ...  21 Jul' 21
# 32  \n  3 - 3.2 LPA                               ...  21 Jul' 21
# 33  \n  3 LPA                                     ...  21 Jul' 21
# 34  \n  3 - 4 LPA                                 ...  19 Jul' 21
# 35  \n  3 - 3.5 LPA                               ...  19 Jul' 21
# 36  \n  3 LPA                                     ...  23 Jul' 21
# 37  \n  3 - 6.5 LPA                               ...  19 Jul' 21
# 38  \n  6 - 7 LPA                                 ...  18 Jul' 21
# 39  \n  3 - 5 LPA                                 ...  18 Jul' 21
#
#                                              location
# 0   \n                        Muskurahat Foundatio...
# 1   \n                        Muskurahat Foundatio...
# 2   \n                        Muskurahat Foundatio...
# 3   \n                        Vaultedge Software P...
# 4   \n                        Softsensor.ai       ...
# 5   \n                        ProtonAutoML        ...
# 6   \n                        ProtonAutoML        ...
# 7   \n                        RoaDo               ...
# 8   \n                        RavGins Internationa...
# 9   \n                        Global Sun          ...
# 10  \n                        Touchstone Partners ...
# 11  \n                        Labellerr By Tensor ...
# 12  \n                        UFaber Edutech      ...
# 13  \n                        Aptigenz Solutions P...
# 14  \n                        Noise               ...
# 15  \n                        RoaDo               ...
# 16  \n                        CrewKarma           ...
# 17  \n                        IQGateway           ...
# 18  \n                        Internshala         ...
# 19  \n                        Mithi Software Techn...
# 20  \n                        White Blink         ...
# 21  \n                        Wono Inc            ...
# 22  \n                        Wono Inc            ...
# 23  \n                        Wono Inc            ...
# 24  \n                        Emertxe Information ...
# 25  \n                        Open Door Education ...
# 26  \n                        Content Beta        ...
# 27  \n                        Softway Solutions Pr...
# 28  \n                        DeepThought Edutech ...
# 29  \n                        Saltoro Coffee Roast...
# 30  \n                        WebMOBI             ...
# 31  \n                        Global Sun          ...
# 32  \n                        Medico Healthcare Se...
# 33  \n                        Edupixels           ...
# 34  \n                        Manufac Analytics Pr...
# 35  \n                        Swabhav Techlabs    ...
# 36  \n                        Claraeon Learning Pr...
# 37  \n                        Picostone           ...
# 38  \n                        AIMonk Labs Technolo...
# 39  \n                        369 Zoss Waters     ...

# %% [markdown]
# # Top 10 ODI batsmen with team

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all("div" , class_ = "rankings-block__container full")
Name = soup.find_all("td" , class_ = "table-body__cell rankings-table__name name")
Name = [i.get_text() for i in Name]
Name = Name[:10]
place = soup.find_all("span" , class_ = "table-body__logo-text")
place = [i.get_text() for i in place]
place = place[:10]
rating = soup.find_all("td" , class_ = "table-body__cell rating")
rating = [i.get_text() for i in rating]
rating = rating[:10]
import pandas as pd
game = pd.DataFrame({})
game["country"] = place
game["Name"] = Name
game["rating"] = rating 
game
# Out:
#   country                     Name rating
# 0     IND          \nVirat Kohli\n    857
# 1     IND         \nRohit Sharma\n    825
# 2      NZ          \nRoss Taylor\n    801
# 3     AUS          \nAaron Finch\n    791
# 4     ENG       \nJonny Bairstow\n    785
# 5     PAK         \nFakhar Zaman\n    778
# 6      SA  \nFrancois du Plessis\n    778
# 7     AUS         \nDavid Warner\n    773
# 8      WI            \nShai Hope\n    773
# 9      SA      \nQuinton de Kock\n    756

# %% [markdown]
# # Top ODI bowlers

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all("div" , class_ = "rankings-block__container full")
Name = soup.find_all("td" , class_ = "table-body__cell rankings-table__name name")
Name = [i.get_text() for i in Name]
place = soup.find_all("span" , class_ = "table-body__logo-text")
place = [i.get_text() for i in place]
rating = soup.find_all("td" , class_ = "table-body__cell rating")
rating = [i.get_text() for i in rating]
import pandas as pd
game = pd.DataFrame({})
game["country"] = place
game["Name"] = Name
game["rating"] = rating
game
# Out:
#    country                  Name rating
# 0      BAN      \nMehedi Hasan\n    713
# 1      AFG  \nMujeeb Ur Rahman\n    708
# 2       NZ        \nMatt Henry\n    691
# 3      IND    \nJasprit Bumrah\n    690
# 4       SA     \nKagiso Rabada\n    666
# ..     ...                   ...    ...
# 94     AUS       \nAshton Agar\n    377
# 95     PAK    \nMohammad Nawaz\n    376
# 96     ZIM   \nDonald Tiripano\n    373
# 97     IRE   \nGeorge Dockrell\n    370
# 98     SCO     \nBradley Wheal\n    368
#
# [99 rows x 3 columns]

# %% [markdown]
# # Top 10 rankings in cricket men

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
soup = BeautifulSoup(page.content, 'html.parser')
ranking_table = soup.find_all("div" , class_ = "rankings-block__container full rankings-table")

# %%
matches = soup.find_all('td' , 'table-body__cell u-center-text')
matches = [i.get_text() for i in matches]

# %%
count = 0
points = []
Matches = []
for i in matches:
    if count % 2 == 0:
        Matches.append(i)
    count += 1
for l in matches:
    if count % 2 == 1:
        points.append(l)
    count += 1

# %%
import pandas as pd
game = pd.DataFrame({})
game["country"] = country
game["no of matches played"] = Matches
game["points"] = points
game["rank"] = rank

# %%
game
# Out:
#              country no of matches played points rank
# 0          Australia                   25  2,945  118
# 1              India                   29  3,344  115
# 2            England                   27  3,100  115
# 3       South Africa                   20  2,137  107
# 4           Pakistan                   24  2,323   97
# 5         Bangladesh                   27  2,438   90
# 6        West Indies                   27  2,222   82
# 7          Sri Lanka                   24  1,876   78
# 8        Afghanistan                   17  1,054   62
# 9        Netherlands                    7    336   48
# 10           Ireland                   21    897   43
# 11          Zimbabwe                   15    588   39
# 12          Scotland                    7    258   37
# 13              Oman                    7    240   34
# 14             Nepal                    5    119   24
# 15               UAE                    9    190   21
# 16           Namibia                    6     97   16
# 17     United States                    8     93   12
# 18  Papua New Guinea                    5      0    0

# %% [markdown]
# # Top ODI womens

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
soup = BeautifulSoup(page.content, 'html.parser')
ranking_table = soup.find_all("div" , class_ = "rankings-block__container full rankings-table")
matches = soup.find_all('td' , 'table-body__cell u-center-text')
matches = [i.get_text() for i in matches]
count = 0
points = []
Matches = []
for i in matches:
    if count % 2 == 0:
        Matches.append(i)
    count += 1
for l in matches:
    if count % 2 == 1:
        points.append(l)
    count += 1
country = soup.find_all('span' , class_ = 'u-hide-phablet')
country = [i.get_text() for i in country]

# %%
ranking = soup.find_all('td' , class_ = 'table-body__cell u-text-right rating')
rank = [i.get_text() for i in ranking]
import pandas as pd
game = pd.DataFrame({})
game["country"] = country
game["no of matches played"] = Matches
game["points"] = points
game["rank"] = rank

# %%
game
# Out:
#         country no of matches played points rank
# 0  South Africa                   24  2,828  118
# 1       England                   17  1,993  117
# 2         India                   20  2,226  111
# 3   New Zealand                   21  1,947   93
# 4   West Indies                   12  1,025   85
# 5      Pakistan                   15  1,101   73
# 6    Bangladesh                    5    306   61
# 7     Sri Lanka                   11    519   47
# 8       Ireland                    2     25   13

# %% [markdown]
# # weather forcast of san fransico

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.YM33g2gzZPY")
soup = BeautifulSoup(page.content, 'html.parser')
period = soup.find_all("p" , class_ = "period-name")
period = [i.get_text() for i in period]
weather = soup.find_all("p" , class_ = "short-desc")
weather = [i.get_text() for i in weather]
import pandas as pd
game = pd.DataFrame({})
game["Period"] = period
game["weather"] = weather

# %%
game
# Out:
#           Period                                   weather
# 0          Today                             BecomingSunny
# 1        Tonight     IncreasingClouds andBreezy thenCloudy
# 2         Friday          Partly Sunnythen Sunnyand Breezy
# 3    FridayNight  Partly Cloudyand Breezythen MostlyCloudy
# 4       Saturday          Mostly Sunnythen Sunnyand Breezy
# 5  SaturdayNight   Mostly Clearand Breezythen MostlyCloudy
# 6         Sunday                              Mostly Sunny
# 7    SundayNight                             Mostly Cloudy
# 8         Monday                              Mostly Sunny

# %% [markdown]
# # Womens all rounder

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
soup = BeautifulSoup(page.content, 'html.parser')
Name = soup.find_all("td" , class_ = "table-body__cell rankings-table__name name")
Name = Name[:9]
Name = [i.get_text() for i in Name]
team = soup.find_all("span" , class_ = "table-body__logo-text")
team = team[:9]
team = [i.get_text() for i in team]
rating = soup.find_all("td" , class_ = "table-body__cell rating")
rating = rating[:9]
rating = [i.get_text() for i in rating]
import pandas as pd
game = pd.DataFrame({})
game["Name"] = Name
game["team"] = team
game["rating"] = rating

# %%
game
# Out:
#                    Name team rating
# 0      \nEllyse Perry\n  AUS    418
# 1   \nStafanie Taylor\n   WI    410
# 2    \nNatalie Sciver\n  ENG    349
# 3     \nDeepti Sharma\n  IND    343
# 4     \nJess Jonassen\n  AUS    307
# 5  \nAshleigh Gardner\n  AUS    252
# 6  \nDane van Niekerk\n   SA    243
# 7     \nSophie Devine\n   NZ    242
# 8       \nAmelia Kerr\n   NZ    236

# %% [markdown]
# # Womens bowling

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling")
soup = BeautifulSoup(page.content, 'html.parser')
Name = soup.find_all("td" , class_ = "table-body__cell rankings-table__name name")
Name = Name[:9]
Name = [i.get_text() for i in Name]
team = soup.find_all("span" , class_ = "table-body__logo-text")
team = team[:9]
team = [i.get_text() for i in team]
rating = soup.find_all("td" , class_ = "table-body__cell rating")
rating = rating[:9]
rating = [i.get_text() for i in rating]
import pandas as pd
game = pd.DataFrame({})
game["Name"] = Name
game["team"] = team
game["rating"] = rating

# %%
game
# Out:
#                   Name team rating
# 0     \nMegan Schutt\n  AUS    762
# 1   \nMarizanne Kapp\n   SA    747
# 2   \nShabnim Ismail\n   SA    717
# 3   \nJhulan Goswami\n  IND    681
# 4  \nKatherine Brunt\n  ENG    655
# 5     \nPoonam Yadav\n  IND    641
# 6   \nAyabonga Khaka\n   SA    638
# 7     \nEllyse Perry\n  AUS    616
# 8    \nShikha Pandey\n  IND    610

# %% [markdown]
# # Womens batting

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")
soup = BeautifulSoup(page.content, 'html.parser')
Name = soup.find_all("td" , class_ = "table-body__cell rankings-table__name name")
Name = Name[:9]
Name = [i.get_text() for i in Name]
team = soup.find_all("span" , class_ = "table-body__logo-text")
team = team[:9]
team = [i.get_text() for i in team]
rating = soup.find_all("td" , class_ = "table-body__cell rating")
rating = rating[:9]
rating = [i.get_text() for i in rating]
import pandas as pd
game = pd.DataFrame({})
game["Name"] = Name
game["team"] = team
game["rating"] = rating

# %%
game
# Out:
#                     Name team rating
# 0        \nLizelle Lee\n   SA    758
# 1       \nAlyssa Healy\n  AUS    756
# 2    \nStafanie Taylor\n   WI    746
# 3        \nMeg Lanning\n  AUS    723
# 4  \nAmy Satterthwaite\n   NZ    715
# 5    \nSmriti Mandhana\n  IND    710
# 6        \nMithali Raj\n  IND    709
# 7     \nNatalie Sciver\n  ENG    685
# 8    \nLaura Wolvaardt\n   SA    683

# %% [markdown]
# # no broker

# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.nobroker.in/property/sale/bangalore/Bangalore?searchParam=W3sibGF0IjoxMi45NzE1OTg3LCJsb24iOjc3LjU5NDU2MjcsInBsYWNlSWQiOiJDaElKYlU2MHlYQVdyanNSNEU5LVVlakQzX2ciLCJwbGFjZU5hbWUiOiJCYW5nYWxvcmUifV0=&radius=2.0&type=BHK4&price=63900000,81720000")
soup = BeautifulSoup(page.content, 'html.parser')
house_title = soup.find_all('h2' , class_ = 'heading-6 font-semi-bold nb__1AShY')
house_title = [i.get_text() for i in house_title]
area = soup.find_all('div' , class_ = 'nb__3oNyC')
area = [i.get_text() for i in area]
location = soup.find_all('div' ,class_ = 'nb__2CMjv')
location = [i.get_text() for i in location]
EMI_price = soup.find_all('div' , class_ = 'font-semi-bold heading-6')
EMI_price = [i.get_text() for i in EMI_price]
count = 0
EMI = []
price = []
starts = []
for i in EMI_price:
    if count % 3 == 0:
        starts.append(i)
    count = count+1
for l in EMI_price:
    if count % 3 == 1:
        EMI.append(l)
    count = count+1
for k in EMI_price:
    if count % 3 == 2:
        price.append(k)
    count += 1
    import pandas as pd
job = pd.DataFrame({})
job["house title"] = house_title
job["location"] = location
job["area"] = area
job["EMI"] = EMI
job["price"] = price
job
# Out:
#                                          house title  \
# 0  4 BHK Apartment  For Sale  In Gajanana Om Niva...
# 1  4 BHK In Independent House  For Sale  In Dodda...
# 2  4 BHK In Independent House  For Sale  In Stand...
# 3  4 BHK Flat  For Sale  In Standalone Building  ...
# 4  4 BHK In Independent House  For Sale  In Krish...
# 5  4 BHK In Independent House  For Sale  In Basav...
# 6             4 BHK Flat  For Sale  In  Rajajinagar
# 7                4 BHK Flat  For Sale  In Sultanpet
# 8  4 BHK For Sale  In Pattandur Agrahara Prestige...
# 9  4 BHK In Independent House  For Sale  In Indir...
#
#                                             location        area  \
# 0             Gajanana Om Nivas Apartment  Murphy Rd  3,600 sqft
# 1  Independent House, Basava Nagar Main Rd, Adars...  2,818 sqft
# 2  Mahalakshmipuram, Near  Mahalakshmipuram Polic...  4,500 sqft
# 3  6th Cross Rd, 6th Block, Near  The Koramangala...  5,700 sqft
# 4  Independent House, Old Madras Rd,  Behind Offi...  2,400 sqft
# 5  Independent House, Maruthi Court 2nd Main Road...  4,500 sqft
# 6  Standalone Building, Yeshwanthpur, Near Columb...  2,700 sqft
# 7  Standalone Building, Sultanpete Main Road, Nea...  3,520 sqft
# 8  Pattandur Agrahara Prestige White Meadows  Whi...  5,000 sqft
# 9  Independent House, Binnamangala,  near to Chai...  2,550 sqft
#
#                 EMI         price
# 0  ₹4.13 Lacs/Month   ₹7.2 Crores
# 1  ₹3.73 Lacs/Month   ₹6.5 Crores
# 2   ₹4.3 Lacs/Month   ₹7.5 Crores
# 3   ₹4.3 Lacs/Month   ₹7.5 Crores
# 4  ₹4.01 Lacs/Month     ₹7 Crores
# 5  ₹4.01 Lacs/Month  ₹6.99 Crores
# 6  ₹4.01 Lacs/Month     ₹7 Crores
# 7  ₹4.01 Lacs/Month     ₹7 Crores
# 8  ₹3.73 Lacs/Month   ₹6.5 Crores
# 9  ₹4.13 Lacs/Month   ₹7.2 Crores
